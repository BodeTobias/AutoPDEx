# %% [markdown]
# # Title

# %% [markdown]
# Description of the notebook, download link, vertical or horizontal method of lines?!

# %%
## example 17: navier stokes with heat conduction and convection and temperature-dependent viscosity
# FIXME: ist der Druck richtig? Starke Oszillationen, aber stabil...

# Tutorial Example: Navier–Stokes with Heat Conduction, Convection, and Temperature-Dependent Viscosity

# %%
import os

import jax
import jax.numpy as jnp
import meshio
from flax.core import FrozenDict

from autopdex import utility, spaces, seeder, models, dae

jax.config.update("jax_enable_x64", True)
# Out:
# Traceback (most recent call last):
#
#   File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\IPython\core\interactiveshell.py:3548 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[4], line 8
#     from autopdex import utility, spaces, seeder, models, dae
#
#   File C:\JAX\autopdex_related\AutoPDEx\autopdex\dae.py:25
#     """
#        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 1550-1551: malformed \N character escape

# %% [markdown]
# Load the mesh that was generated with GMSH

# %%
# Load meshes generated with gmsh
mesh = meshio.read(r"C:\JAX\autopdex_related\autopdex\examples\meshes\navier_stokes_mesh_v.msh")
coords_v = jnp.asarray(mesh.points[:, :2])
cells_v = jnp.asarray(mesh.cells_dict["triangle6"])

mesh = meshio.read(r"C:\JAX\autopdex_related\autopdex\examples\meshes\navier_stokes_mesh_p.msh")
coords_p = jnp.asarray(mesh.points[:, :2])
cells_p = jnp.asarray(mesh.cells_dict["triangle"])

coords_T = coords_v
cells_T = cells_v

# Extend node coordinates to include the temperature field (using the velocity nodes)
node_coordinates = {
  '1velocity': coords_v,
  '2pressure': coords_p,
  '3temperature': coords_T,
}

# %% [markdown]
# ## Boundary conditions:
#  - Parabolic inflow at x = 0,
#  - p = 0 at x = L (outflow),
#  - No-slip on the cylinder and top/bottom walls.
#
#  - Inflow (x = 0): T = 0 (Dirichlet)
#  - Cylinder: T ramps from 0 to 20 over the first 3.5 seconds (Dirichlet)
#  - Top and bottom walls: insulated (Neumann, natural condition)

# %%
def on_left(x):
  return jnp.isclose(x[:, 0], 0.0)

selection_v_left = utility.dof_select(on_left(coords_v), jnp.asarray([True, True]))

def on_top_bottom_circle(x):
  # For velocity: top/bottom walls and cylinder (no-slip)
  return (jnp.isclose(x[:, 1], 0.0) + jnp.isclose(x[:, 1], 0.41) + jnp.isclose(
      (x[:, 0] - 0.2)**2 + (x[:, 1] - 0.2)**2, 0.05**2))

selection_v_remaining = utility.dof_select(on_top_bottom_circle(coords_v), jnp.asarray([True, True]))

def on_right(x):
  # return jnp.isclose(x[:, 0], 2.2)
  return jnp.isclose(x, jnp.array([2.2, 0.])).all(axis=1)

selection_p = utility.dof_select(on_right(coords_p), jnp.asarray([True]))

def on_left_temp(x):
  return jnp.isclose(x[:, 0], 0.0)

selection_temp_left = utility.dof_select(on_left_temp(coords_T), jnp.asarray([True]))

def on_cylinder(x):
  # Cylinder boundary (tolerance may be added if needed)
  return jnp.isclose((x[:, 0] - 0.2)**2 + (x[:, 1] - 0.2)**2, 0.05**2)

selection_temp_cylinder = utility.dof_select(on_cylinder(coords_T), jnp.asarray([True]))

# Combine Dirichlet selections for temperature
selection_temp = selection_temp_left + selection_temp_cylinder

# Combine Dirichlet dofs for all fields
dirichlet_dofs = {
  '1velocity': selection_v_left + selection_v_remaining,
  '2pressure': selection_p,
  '3temperature': selection_temp,
}

# Set initial Dirichlet conditions
dirichlet_conditions = utility.dict_zeros_like(dirichlet_dofs, dtype=jnp.float64)

# %%
# Time-dependent Dirichlet condition for the velocity inflow
def get_dirichlet_conditions(t):

  def condition(y_coor):
    u_max = 1.5
    u = 4 * u_max * y_coor * (0.41 - y_coor) / 0.41**2

    # 3.5 seconds sinusoidal ramp-up, then constant
    cond_list = [t <= 3.5, t > 3.5]
    func_list = [u * jnp.sin(jnp.pi / 7 * t), u]
    return jnp.asarray([jnp.piecewise(t, cond_list, func_list), 0.])

  new_values = jax.vmap(condition)(coords_v[:, 1])
  return jnp.where(selection_v_left, new_values, 0.0)

def pre_step_updates(t, settings):
  settings['current time'] = t

  # Update velocity boundary conditions at time t
  new_dirichlet = get_dirichlet_conditions(t)
  settings['dirichlet conditions']['1velocity'] = new_dirichlet

  # Update temperature boundary conditions at time t
  new_temp_bc = jnp.zeros_like(dirichlet_dofs['3temperature'], dtype=jnp.float64)
  # Cylinder temperature: ramp from 0 to 20 within the first 3.5 seconds
  cylinder_temp = jnp.where(t <= 3.5, 20 * jnp.sin(jnp.pi / 7 * t), 20.0)
  new_temp_bc = new_temp_bc.at[selection_temp_cylinder].set(cylinder_temp)
  settings['dirichlet conditions']['3temperature'] = new_temp_bc

  return settings

# %% [markdown]
# ### Weak formulation: Coupled equations (Navier–Stokes and Energy)

# %%
def weak_form_integrand(x_int, trial_ansatz, test_ansatz, settings, static_settings, elem_number, set):
  """
  Local integrand of the coupled equations:

  Navier–Stokes:
    ∂ₜ u + (u · ∇) u - ν Δ u + ∇ p = f,   and   div(u) = 0

  Energy (Temperature) equation:
    ∂ₜ T + u · ∇ T - α Δ T = 0

  Coupling is achieved through the convection term (u · ∇ T) and a temperature-dependent viscosity.
  """
  t = settings['current time']

  # Pressure (p) and test function (q)
  p = trial_ansatz['2pressure'](x_int, t)[0]
  q = test_ansatz['2pressure'](x_int)[0]

  # Velocity (u) and its derivatives
  u = trial_ansatz['1velocity'](x_int, t)
  grad_u, du_dt = jax.jacfwd(trial_ansatz['1velocity'], (0, 1))(x_int, t)
  du_dt = du_dt.flatten()  # flatten to obtain a vector

  # Test function (v) and its derivatives
  v = test_ansatz['1velocity'](x_int)
  grad_v = jax.jacfwd(test_ansatz['1velocity'])(x_int)

  # Temperature (T) and test function (φ)
  T_val = trial_ansatz['3temperature'](x_int, t)[0]
  grad_T, dT_dt = jax.jacfwd(trial_ansatz['3temperature'], (0, 1))(x_int, t)
  grad_T = grad_T.flatten()
  dT_dt = dT_dt[0]
  phi = test_ansatz['3temperature'](x_int)[0]
  grad_phi = jax.jacfwd(test_ansatz['3temperature'])(x_int)
  grad_phi = grad_phi.flatten()

  # Divergence of u and v
  div_u = grad_u[0, 0] + grad_u[1, 1]
  div_v = grad_v[0, 0] + grad_v[1, 1]

  # Convective term: (u · ∇) u
  conv_u = jnp.einsum('j,ij->i', u, grad_u)

  # Temperature-dependent viscosity:
  # Base viscosity and temperature coefficient
  nu0 = 0.001
  beta = 0.05
  nu = nu0 * (1 + beta * T_val)

  # Weak form of the momentum equation
  weak_momentum = (du_dt @ v + conv_u @ v + nu * jnp.einsum('ij,ij->', grad_u, grad_v) - p * div_v)

  # Weak form of the continuity equation
  weak_continuity = -q * div_u

  # Thermal diffusivity parameter (α)
  alpha = 0.001

  # Weak form of the energy (temperature) equation
  weak_energy = (dT_dt * phi + (u @ grad_T) * phi + alpha * jnp.dot(grad_T, grad_phi))

  return weak_momentum + weak_continuity + weak_energy

# %% [markdown]
# ### Set-up the element and time stepping procedure

# %%
# Ansatz functions for the fields
ansatz_fun = {
  '1velocity': spaces.fem_iso_line_tri_tet,  # quadratic (6 nodes per triangle)
  '2pressure': spaces.fem_iso_line_tri_tet,  # linear (3 nodes per triangle)
  '3temperature': spaces.fem_iso_line_tri_tet,
}

# Numerical integration
ref_int_coor, ref_int_weights = seeder.int_pts_ref_tri(order=4)

# Set-up the 'user residual' based on a weak-in-space formulation of the PDEs.
user_residual = models.mixed_reference_domain_residual_time(
    weak_form_integrand,
    ansatz_fun,
    ref_int_coor,
    ref_int_weights,
    mapping_key='1velocity',
)

# The settings are analougs to static analyses. Additionally, the 'current time' has to be initialized.
settings = {
  'connectivity': ({
    '1velocity': cells_v,
    '2pressure': cells_p,
    '3temperature': cells_T,
  },),
  'node coordinates': node_coordinates,
  'dirichlet dofs': dirichlet_dofs,
  'dirichlet conditions': dirichlet_conditions,
  'current time': 0.0,
}

# The static settings are also passed to the PDE functions. 
# When used through the time stepping manager, also the 'dae' and 'time integrators' have to be specified.
static_settings = FrozenDict({
  'assembling mode': ('user residual',),
  'solution structure': ('nodal imposition',),
  'model': (user_residual,),
  'solver type': 'newton',
  'solver backend': 'pardiso',
  'solver': 'lu',
  'verbose': 2,
  'dae': 'call pde',    # Here we need the keyword 'call pde' in order to call the assembling routines for PDE specified by the 'model'.
  'time integrators': {
    '1velocity': dae.BackwardDiffFormula(2),
    '2pressure': dae.BackwardEuler(),     # The time derivative is not used, but an integrator has to be specified, 
                                          #   that is compatible with the stages of the other fields
    '3temperature': dae.AdamsMoulton(1),
  },
})

# Define the postprocessing policy and pass the function for pre-step updates
manager = dae.TimeSteppingManager(static_settings,
                              save_policy=dae.SaveAllPolicy(),
                              pre_step_updates=pre_step_updates)

# Start with zero velocity and temperature
initial_conditions = {
  '1velocity': jnp.zeros((coords_v.shape[0], 2)),
  '2pressure': jnp.zeros((coords_p.shape[0], 1)),
  '3temperature': jnp.zeros((coords_T.shape[0], 1)),
}

# %% [markdown]
# ### Run the time stepping loop

# %%
t_final = 10
num_time_steps = 500
result = manager.run(initial_conditions, t_final / num_time_steps, t_final, num_time_steps, settings)
# Out:
# Iteration 0, Residual norm: 0.017871636935677313
# Iteration 1, Residual norm: 2.7893455422508244e-05
# Iteration 2, Residual norm: 2.958197350170137e-09
#
# Iteration 0, Residual norm: 0.0206150592227377
# Iteration 1, Residual norm: 2.966663907177073e-05
# Iteration 2, Residual norm: 3.326061805516559e-09
#
# Iteration 0, Residual norm: 0.019308199656803162
# Iteration 1, Residual norm: 3.102969915275309e-05
# Iteration 2, Residual norm: 3.591165225103608e-09
#
# Iteration 0, Residual norm: 0.019598169197754815
# Iteration 1, Residual norm: 3.2099560389401873e-05
# Iteration 2, Residual norm: 3.632903549363982e-09
#
# Iteration 0, Residual norm: 0.019287899062661346
# Iteration 1, Residual norm: 3.31972707202325e-05
# Iteration 2, Residual norm: 3.6187549147290605e-09
#
# Iteration 0, Residual norm: 0.019522235727412112
# Iteration 1, Residual norm: 3.4250630441905934e-05
# Iteration 2, Residual norm: 3.697037020571628e-09
#
# Iteration 0, Residual norm: 0.019217692946893274
# Iteration 1, Residual norm: 3.533793052965378e-05
# Iteration 2, Residual norm: 3.9590787013851184e-09
#
# Iteration 0, Residual norm: 0.019417162416353245
# Iteration 1, Residual norm: 3.660653750947797e-05
# Iteration 2, Residual norm: 4.28215610590758e-09
#
# Iteration 0, Residual norm: 0.019127471747834163
# Iteration 1, Residual norm: 3.818931512016977e-05
# Iteration 2, Residual norm: 4.568410150022934e-09
#
# Iteration 0, Residual norm: 0.019314821047983842
# Iteration 1, Residual norm: 4.006843707519683e-05
# Iteration 2, Residual norm: 4.726670063437271e-09
#
# Iteration 0, Residual norm: 0.01906029345186386
# Iteration 1, Residual norm: 4.212078416026162e-05
# Iteration 2, Residual norm: 4.690494265005771e-09
#
# Iteration 0, Residual norm: 0.01926397681135199
# Iteration 1, Residual norm: 4.4100775192526064e-05
# Iteration 2, Residual norm: 4.456844983718333e-09
#
# Iteration 0, Residual norm: 0.019070238541811384
# Iteration 1, Residual norm: 4.57422026174099e-05
# Iteration 2, Residual norm: 4.13090228715321e-09
#
# Iteration 0, Residual norm: 0.01931352822969838
# Iteration 1, Residual norm: 4.6897279052705803e-05
# Iteration 2, Residual norm: 3.911909079445967e-09
#
# Iteration 0, Residual norm: 0.01919439853964769
# Iteration 1, Residual norm: 4.759611184966465e-05
# Iteration 2, Residual norm: 3.986760195438344e-09
# Progress: 3%, Time: 9.00e-01, accepted step: True, dt: 6.00e-02, iterations: 2
#
# Iteration 0, Residual norm: 0.019479868343508778
# Iteration 1, Residual norm: 4.803367162577968e-05
# Iteration 2, Residual norm: 4.206649551580639e-09
#
# Iteration 0, Residual norm: 0.019423181557882738
# Iteration 1, Residual norm: 4.8518882993243924e-05
# Iteration 2, Residual norm: 4.254356474060185e-09
#
# Iteration 0, Residual norm: 0.019724085910218674
# Iteration 1, Residual norm: 4.917584131978007e-05
# Iteration 2, Residual norm: 4.002716439252815e-09
#
# Iteration 0, Residual norm: 0.01969228917795015
# Iteration 1, Residual norm: 4.9976860058775335e-05
# Iteration 2, Residual norm: 3.5360383320397636e-09
#
# Iteration 0, Residual norm: 0.01997268210132358
# Iteration 1, Residual norm: 5.087472101928933e-05
# Iteration 2, Residual norm: 3.053498134557152e-09
#
# Iteration 0, Residual norm: 0.019936452301247236
# Iteration 1, Residual norm: 5.1576902275288875e-05
# Iteration 2, Residual norm: 2.667262342175829e-09
#
# Iteration 0, Residual norm: 0.020181690130171757
# Iteration 1, Residual norm: 5.199418825027106e-05
# Iteration 2, Residual norm: 2.3833300418359043e-09
#
# Iteration 0, Residual norm: 0.020134321391295586
# Iteration 1, Residual norm: 5.216343033336957e-05
# Iteration 2, Residual norm: 2.169703312638723e-09
#
# Iteration 0, Residual norm: 0.020343740595652644
# Iteration 1, Residual norm: 5.1931170603348175e-05
# Iteration 2, Residual norm: 1.968904180355415e-09
#
# Iteration 0, Residual norm: 0.02028168478129273
# Iteration 1, Residual norm: 5.1280399835524055e-05
# Iteration 2, Residual norm: 1.7569029732264827e-09
#
# Iteration 0, Residual norm: 0.02045335192999717
# Iteration 1, Residual norm: 5.026904055239245e-05
# Iteration 2, Residual norm: 1.544146015967066e-09
#
# Iteration 0, Residual norm: 0.020374952031135957
# Iteration 1, Residual norm: 4.8962526206958984e-05
# Iteration 2, Residual norm: 1.3488333477181561e-09
#
# Iteration 0, Residual norm: 0.02051110719630793
# Iteration 1, Residual norm: 4.739059899707744e-05
# Iteration 2, Residual norm: 1.1892305388862217e-09
#
# Iteration 0, Residual norm: 0.020416164467230595
# Iteration 1, Residual norm: 4.565609033410144e-05
# Iteration 2, Residual norm: 1.0739623010164571e-09
#
# Iteration 0, Residual norm: 0.020512047117982414
# Iteration 1, Residual norm: 4.396870332303312e-05
# Iteration 2, Residual norm: 9.874587778104167e-10
#
# Iteration 0, Residual norm: 0.020387322534305086
# Iteration 1, Residual norm: 4.232970464789866e-05
# Iteration 2, Residual norm: 9.015901714719839e-10
#
# Iteration 0, Residual norm: 0.020432137023945505
# Iteration 1, Residual norm: 4.0701704664098335e-05
# Iteration 2, Residual norm: 8.045438120463416e-10
#
# Iteration 0, Residual norm: 0.02027462373869934
# Iteration 1, Residual norm: 3.913175027793628e-05
# Iteration 2, Residual norm: 7.120590256151938e-10
#
# Iteration 0, Residual norm: 0.020275147487004798
# Iteration 1, Residual norm: 3.762549072165566e-05
# Iteration 2, Residual norm: 6.467643431533638e-10
#
# Iteration 0, Residual norm: 0.020095475368995187
# Iteration 1, Residual norm: 3.6159012686914925e-05
# Iteration 2, Residual norm: 6.056780315438396e-10
#
# Iteration 0, Residual norm: 0.02006300206374779
# Iteration 1, Residual norm: 3.475279051837978e-05
# Iteration 2, Residual norm: 5.625219931646086e-10
#
# Iteration 0, Residual norm: 0.019862154153834976
# Iteration 1, Residual norm: 3.347174730187396e-05
# Iteration 2, Residual norm: 5.01560299798821e-10
#
# Iteration 0, Residual norm: 0.01978594597197105
# Iteration 1, Residual norm: 3.220165716881103e-05
# Iteration 2, Residual norm: 4.363530292262188e-10
#
# Iteration 0, Residual norm: 0.019552544644453215
# Iteration 1, Residual norm: 3.08547310473903e-05
# Iteration 2, Residual norm: 3.889391800305939e-10
#
# Iteration 0, Residual norm: 0.019434593103812473
# Iteration 1, Residual norm: 2.948395809837356e-05
# Iteration 2, Residual norm: 3.5659548889833274e-10
# Progress: 8%, Time: 2.40e+00, accepted step: True, dt: 6.00e-02, iterations: 2
#
# Iteration 0, Residual norm: 0.01917963748686665
# Iteration 1, Residual norm: 2.8101783492977044e-05
# Iteration 2, Residual norm: 3.1936479610163653e-10
#
# Iteration 0, Residual norm: 0.01903256127695594
# Iteration 1, Residual norm: 2.6710583077853737e-05
# Iteration 2, Residual norm: 2.758801819196502e-10
#
# Iteration 0, Residual norm: 0.018765958448734948
# Iteration 1, Residual norm: 2.5307854870611833e-05
# Iteration 2, Residual norm: 2.426828485923606e-10
#
# Iteration 0, Residual norm: 0.018594452787161465
# Iteration 1, Residual norm: 2.387947906629586e-05
# Iteration 2, Residual norm: 2.2501935386971695e-10
#
# Iteration 0, Residual norm: 0.018307079493946842
# Iteration 1, Residual norm: 2.237525302970041e-05
# Iteration 2, Residual norm: 2.0656443483790488e-10
#
# Iteration 0, Residual norm: 0.018075863670113095
# Iteration 1, Residual norm: 2.0778572475564186e-05
# Iteration 2, Residual norm: 1.7738909371473053e-10
#
# Iteration 0, Residual norm: 0.017692630694426992
# Iteration 1, Residual norm: 1.9131009792726373e-05
# Iteration 2, Residual norm: 1.4770892888289038e-10
#
# Iteration 0, Residual norm: 0.017287548155605927
# Iteration 1, Residual norm: 1.7426942496899487e-05
# Iteration 2, Residual norm: 1.2961879201135141e-10
#
# Iteration 0, Residual norm: 0.016681117816722067
# Iteration 1, Residual norm: 1.5643980681105966e-05
# Iteration 2, Residual norm: 1.1745521057846176e-10
#
# Iteration 0, Residual norm: 0.015999591976858966
# Iteration 1, Residual norm: 1.3966446860065701e-05
# Iteration 2, Residual norm: 1.0155779924644502e-10
#
# Iteration 0, Residual norm: 0.015095727569232052
# Iteration 1, Residual norm: 1.2615429625719763e-05
# Iteration 2, Residual norm: 8.451708436075225e-11
#
# Iteration 0, Residual norm: 0.014109952768939511
# Iteration 1, Residual norm: 1.1484594030330031e-05
# Iteration 2, Residual norm: 7.370089947281649e-11
#
# Iteration 0, Residual norm: 0.013024771822246988
# Iteration 1, Residual norm: 1.0355557433736148e-05
# Iteration 2, Residual norm: 6.709185708006366e-11
#
# Iteration 0, Residual norm: 0.012087280700357878
# Iteration 1, Residual norm: 9.286774284877368e-06
# Iteration 2, Residual norm: 5.794968978020148e-11
#
# Iteration 0, Residual norm: 0.011278494095861473
# Iteration 1, Residual norm: 8.471210812384951e-06
# Iteration 2, Residual norm: 4.698967731474163e-11
#
# Iteration 0, Residual norm: 0.010641071368696535
# Iteration 1, Residual norm: 7.886064823032921e-06
# Iteration 2, Residual norm: 3.9370854154718935e-11
#
# Iteration 0, Residual norm: 0.010035747573155871
# Iteration 1, Residual norm: 7.384300812440619e-06
# Iteration 2, Residual norm: 3.534883980829092e-11
#
# Iteration 0, Residual norm: 0.009467551269292638
# Iteration 1, Residual norm: 6.925424094262303e-06
# Iteration 2, Residual norm: 3.1244313103586996e-11
#
# Iteration 0, Residual norm: 0.008913686872672178
# Iteration 1, Residual norm: 6.4917060447323755e-06
# Iteration 2, Residual norm: 2.6068068239464603e-11
#
# Iteration 0, Residual norm: 0.008410938556912197
# Iteration 1, Residual norm: 6.069635661724226e-06
# Iteration 2, Residual norm: 2.16108679640847e-11
#
# Iteration 0, Residual norm: 0.007973854385525083
# Iteration 1, Residual norm: 5.7760900596378794e-06
# Iteration 2, Residual norm: 1.9686278036624632e-11
#
# Iteration 0, Residual norm: 0.007574331265369471
# Iteration 1, Residual norm: 5.543036625728113e-06
# Iteration 2, Residual norm: 1.9074027181827818e-11
#
# Iteration 0, Residual norm: 0.007190402872667705
# Iteration 1, Residual norm: 5.3103343678656326e-06
# Iteration 2, Residual norm: 1.7651015087931383e-11
#
# Iteration 0, Residual norm: 0.006826074679302351
# Iteration 1, Residual norm: 5.030132951175564e-06
# Iteration 2, Residual norm: 1.4651856474053724e-11
#
# Iteration 0, Residual norm: 0.006486082517454384
# Iteration 1, Residual norm: 4.672709095229693e-06
# Iteration 2, Residual norm: 1.1045697953524544e-11
# Progress: 13%, Time: 3.90e+00, accepted step: True, dt: 6.00e-02, iterations: 2
#
# Iteration 0, Residual norm: 0.006160661380452178
# Iteration 1, Residual norm: 4.237868976857962e-06
# Iteration 2, Residual norm: 8.007982916924592e-12
#
# Iteration 0, Residual norm: 0.0058409309883035955
# Iteration 1, Residual norm: 3.755054166029418e-06
# Iteration 2, Residual norm: 5.916986611781483e-12
#
# Iteration 0, Residual norm: 0.00553024469635866
# Iteration 1, Residual norm: 3.2815402753665958e-06
# Iteration 2, Residual norm: 4.523143811751663e-12
#
# Iteration 0, Residual norm: 0.005234294943709387
# Iteration 1, Residual norm: 2.876040621932092e-06
# Iteration 2, Residual norm: 3.526798932012618e-12
#
# Iteration 0, Residual norm: 0.004953786792981421
# Iteration 1, Residual norm: 2.5539265384058556e-06
# Iteration 2, Residual norm: 2.7917083437631417e-12
#
# Iteration 0, Residual norm: 0.004692260090909664
# Iteration 1, Residual norm: 2.2856022608469905e-06
# Iteration 2, Residual norm: 2.2837426215709216e-12
#
# Iteration 0, Residual norm: 0.004451930261095723
# Iteration 1, Residual norm: 2.0609436550032815e-06
# Iteration 2, Residual norm: 1.9455821478436164e-12
#
# Iteration 0, Residual norm: 0.004228346396947183
# Iteration 1, Residual norm: 1.8882866803812632e-06
# Iteration 2, Residual norm: 1.6306527276431172e-12
#
# Iteration 0, Residual norm: 0.004016733730553438
# Iteration 1, Residual norm: 1.7461154862129966e-06
# Iteration 2, Residual norm: 1.3594419452771287e-12
#
# Iteration 0, Residual norm: 0.0038162109041912015
# Iteration 1, Residual norm: 1.624271772050906e-06
# Iteration 2, Residual norm: 1.1672683730022417e-12
#
# Iteration 0, Residual norm: 0.0036256837535732687
# Iteration 1, Residual norm: 1.5172396652047406e-06
# Iteration 2, Residual norm: 1.0249767056045106e-12
#
# Iteration 0, Residual norm: 0.0034436159764222314
# Iteration 1, Residual norm: 1.4179688221401158e-06
# Iteration 2, Residual norm: 8.915978605199263e-13
#
# Iteration 0, Residual norm: 0.003273879354858101
# Iteration 1, Residual norm: 1.3246246412524492e-06
# Iteration 2, Residual norm: 7.695301493056637e-13
#
# Iteration 0, Residual norm: 0.003118635398655916
# Iteration 1, Residual norm: 1.234298111739057e-06
# Iteration 2, Residual norm: 6.720712940285731e-13
#
# Iteration 0, Residual norm: 0.0029730607107587665
# Iteration 1, Residual norm: 1.1516319285302825e-06
# Iteration 2, Residual norm: 5.8761832074095e-13
#
# Iteration 0, Residual norm: 0.0028332460835935884
# Iteration 1, Residual norm: 1.0755258828816645e-06
# Iteration 2, Residual norm: 5.072815925131812e-13
#
# Iteration 0, Residual norm: 0.0027004597628198274
# Iteration 1, Residual norm: 1.0054136353368148e-06
# Iteration 2, Residual norm: 4.3373984425980775e-13
#
# Iteration 0, Residual norm: 0.002574291711420861
# Iteration 1, Residual norm: 9.428442680169697e-07
# Iteration 2, Residual norm: 3.7373957456000624e-13
#
# Iteration 0, Residual norm: 0.002453089817456735
# Iteration 1, Residual norm: 8.845207430932191e-07
# Iteration 2, Residual norm: 3.2106132247915295e-13
#
# Iteration 0, Residual norm: 0.0023412633860443385
# Iteration 1, Residual norm: 8.32582243756962e-07
# Iteration 2, Residual norm: 2.7106383281580554e-13
#
# Iteration 0, Residual norm: 0.0022430961009293976
# Iteration 1, Residual norm: 7.868579054112606e-07
# Iteration 2, Residual norm: 2.2888643346980633e-13
#
# Iteration 0, Residual norm: 0.0021545905204613126
# Iteration 1, Residual norm: 7.457627206557128e-07
# Iteration 2, Residual norm: 1.9613326672389484e-13
#
# Iteration 0, Residual norm: 0.0020708312265991014
# Iteration 1, Residual norm: 7.093983227254594e-07
# Iteration 2, Residual norm: 1.68920884214552e-13
#
# Iteration 0, Residual norm: 0.0019935390566357216
# Iteration 1, Residual norm: 6.739848510850921e-07
# Iteration 2, Residual norm: 1.4619658045204639e-13
#
# Iteration 0, Residual norm: 0.001922903026749792
# Iteration 1, Residual norm: 6.419329423271941e-07
# Iteration 2, Residual norm: 1.2935336328448988e-13
# Progress: 18%, Time: 5.40e+00, accepted step: True, dt: 6.00e-02, iterations: 2
#
# Iteration 0, Residual norm: 0.0018537598943004763
# Iteration 1, Residual norm: 6.105558007322842e-07
# Iteration 2, Residual norm: 1.1584181577108084e-13
#
# Iteration 0, Residual norm: 0.0017847531355828826
# Iteration 1, Residual norm: 5.776490076299895e-07
# Iteration 2, Residual norm: 1.0172383266880314e-13
#
# Iteration 0, Residual norm: 0.0017199913838030392
# Iteration 1, Residual norm: 5.450989042274479e-07
# Iteration 2, Residual norm: 8.856391007156479e-14
#
# Iteration 0, Residual norm: 0.0016593619482983685
# Iteration 1, Residual norm: 5.140321108337495e-07
# Iteration 2, Residual norm: 7.811854382170779e-14
#
# Iteration 0, Residual norm: 0.0015988402196813482
# Iteration 1, Residual norm: 4.868578619425464e-07
# Iteration 2, Residual norm: 6.908816373148085e-14
#
# Iteration 0, Residual norm: 0.0015393256034839458
# Iteration 1, Residual norm: 4.6088665847806004e-07
# Iteration 2, Residual norm: 6.113915084045475e-14
#
# Iteration 0, Residual norm: 0.0014835807789415267
# Iteration 1, Residual norm: 4.359233096350687e-07
# Iteration 2, Residual norm: 5.568962661439888e-14
#
# Iteration 0, Residual norm: 0.0014282242646311667
# Iteration 1, Residual norm: 4.1188911870899426e-07
# Iteration 2, Residual norm: 5.190322019639193e-14
#
# Iteration 0, Residual norm: 0.0013688849206518188
# Iteration 1, Residual norm: 3.887411010924216e-07
# Iteration 2, Residual norm: 4.717212487330114e-14
#
# Iteration 0, Residual norm: 0.0013096934205073236
# Iteration 1, Residual norm: 3.6768420234304455e-07
# Iteration 2, Residual norm: 4.1837479553402574e-14
#
# Iteration 0, Residual norm: 0.001256666798165291
# Iteration 1, Residual norm: 3.475006727778902e-07
# Iteration 2, Residual norm: 3.7605669914284476e-14
#
# Iteration 0, Residual norm: 0.001207200474019239
# Iteration 1, Residual norm: 3.2928765167722037e-07
# Iteration 2, Residual norm: 3.40732598845998e-14
#
# Iteration 0, Residual norm: 0.0011566011564508834
# Iteration 1, Residual norm: 3.1398947292032566e-07
# Iteration 2, Residual norm: 3.041682911509651e-14
#
# Iteration 0, Residual norm: 0.001107698373652423
# Iteration 1, Residual norm: 2.9801695169546484e-07
# Iteration 2, Residual norm: 2.765824932446058e-14
#
# Iteration 0, Residual norm: 0.0010634471049387486
# Iteration 1, Residual norm: 2.831852329675481e-07
# Iteration 2, Residual norm: 2.6277570929333933e-14
#
# Iteration 0, Residual norm: 0.001019971357445582
# Iteration 1, Residual norm: 2.700467996383203e-07
# Iteration 2, Residual norm: 2.4750107806277826e-14
#
# Iteration 0, Residual norm: 0.0009759698273032874
# Iteration 1, Residual norm: 2.5705409690599186e-07
# Iteration 2, Residual norm: 2.240607207535019e-14
#
# Iteration 0, Residual norm: 0.0009379869665910089
# Iteration 1, Residual norm: 2.441092335570576e-07
# Iteration 2, Residual norm: 2.0301672505270217e-14
#
# Iteration 0, Residual norm: 0.0009075804503499457
# Iteration 1, Residual norm: 2.3208010103943854e-07
# Iteration 2, Residual norm: 1.8733884481822796e-14
#
# Iteration 0, Residual norm: 0.0008775144996892988
# Iteration 1, Residual norm: 2.2214829640369146e-07
# Iteration 2, Residual norm: 1.703892687574634e-14
#
# Iteration 0, Residual norm: 0.0008459066537122751
# Iteration 1, Residual norm: 2.122345810161034e-07
# Iteration 2, Residual norm: 1.5336075153907994e-14
#
# Iteration 0, Residual norm: 0.0008182222522126789
# Iteration 1, Residual norm: 2.0293104182991269e-07
# Iteration 2, Residual norm: 1.4360407829536272e-14
#
# Iteration 0, Residual norm: 0.0007934819190049366
# Iteration 1, Residual norm: 1.944659993468932e-07
# Iteration 2, Residual norm: 1.370551104212693e-14
#
# Iteration 0, Residual norm: 0.00076585776927485
# Iteration 1, Residual norm: 1.8617893945817892e-07
# Iteration 2, Residual norm: 1.2631834790929248e-14
#
# Iteration 0, Residual norm: 0.0007382468718339878
# Iteration 1, Residual norm: 1.7783081197075466e-07
# Iteration 2, Residual norm: 1.1405630906164189e-14
# Progress: 23%, Time: 6.90e+00, accepted step: True, dt: 6.00e-02, iterations: 2
#
# Iteration 0, Residual norm: 0.0007172111080982078
# Iteration 1, Residual norm: 1.700346629112244e-07
# Iteration 2, Residual norm: 1.053992779464032e-14
#
# Iteration 0, Residual norm: 0.000699125183046558
# Iteration 1, Residual norm: 1.6289344736449266e-07
# Iteration 2, Residual norm: 9.760295687631429e-15
#
# Iteration 0, Residual norm: 0.0006778381698681242
# Iteration 1, Residual norm: 1.561501074626804e-07
# Iteration 2, Residual norm: 8.799465567108283e-15
#
# Iteration 0, Residual norm: 0.0006570206885444609
# Iteration 1, Residual norm: 1.4947509918163846e-07
# Iteration 2, Residual norm: 8.047805463635226e-15
#
# Iteration 0, Residual norm: 0.000640740767324193
# Iteration 1, Residual norm: 1.4355474701517833e-07
# Iteration 2, Residual norm: 7.645046315714835e-15
#
# Iteration 0, Residual norm: 0.0006237800768613234
# Iteration 1, Residual norm: 1.3777783286379544e-07
# Iteration 2, Residual norm: 7.159880592586859e-15
#
# Iteration 0, Residual norm: 0.0006033674655521334
# Iteration 1, Residual norm: 1.318310990153748e-07
# Iteration 2, Residual norm: 6.478522873506506e-15
#
# Iteration 0, Residual norm: 0.0005860104421614888
# Iteration 1, Residual norm: 1.2630315485727902e-07
# Iteration 2, Residual norm: 5.922894979281339e-15
#
# Iteration 0, Residual norm: 0.0005737625457275539
# Iteration 1, Residual norm: 1.2110406690675777e-07
# Iteration 2, Residual norm: 5.537557679155221e-15
#
# Iteration 0, Residual norm: 0.0005598862087730895
# Iteration 1, Residual norm: 1.162692350259628e-07
# Iteration 2, Residual norm: 5.059433301240344e-15
#
# Iteration 0, Residual norm: 0.0005433509453804776
# Iteration 1, Residual norm: 1.1128974005803646e-07
# Iteration 2, Residual norm: 4.564035949852779e-15
#
# Iteration 0, Residual norm: 0.0005301421810295937
# Iteration 1, Residual norm: 1.0689053304357037e-07
# Iteration 2, Residual norm: 4.257760447230927e-15
#
# Iteration 0, Residual norm: 0.0005193677057100385
# Iteration 1, Residual norm: 1.0270286084367819e-07
# Iteration 2, Residual norm: 4.034968492297228e-15
#
# Iteration 0, Residual norm: 0.0005051807515121346
# Iteration 1, Residual norm: 9.845386767746707e-08
# Iteration 2, Residual norm: 3.696811556395623e-15
#
# Iteration 0, Residual norm: 0.0004900390369442172
# Iteration 1, Residual norm: 9.424624184954227e-08
# Iteration 2, Residual norm: 3.3463779543917943e-15
#
# Iteration 0, Residual norm: 0.00047963380968885105
# Iteration 1, Residual norm: 9.045420693579543e-08
# Iteration 2, Residual norm: 3.1175375039286088e-15
#
# Iteration 0, Residual norm: 0.0004706032738865024
# Iteration 1, Residual norm: 8.684523846789745e-08
# Iteration 2, Residual norm: 2.8975384738705642e-15
#
# Iteration 0, Residual norm: 0.00045807173816372177
# Iteration 1, Residual norm: 8.322780814480087e-08
# Iteration 2, Residual norm: 2.6177906439913334e-15
#
# Iteration 0, Residual norm: 0.00044594331714010576
# Iteration 1, Residual norm: 7.977589947752851e-08
# Iteration 2, Residual norm: 2.4014472169500753e-15
#
# Iteration 0, Residual norm: 0.0004376553254933329
# Iteration 1, Residual norm: 7.669316952879092e-08
# Iteration 2, Residual norm: 2.2700244941381163e-15
#
# Iteration 0, Residual norm: 0.00042840165339523995
# Iteration 1, Residual norm: 7.362269981036413e-08
# Iteration 2, Residual norm: 2.115286944188921e-15
#
# Iteration 0, Residual norm: 0.00041595467376388025
# Iteration 1, Residual norm: 7.045533592812784e-08
# Iteration 2, Residual norm: 1.9120284621202817e-15
#
# Iteration 0, Residual norm: 0.00040574016001003086
# Iteration 1, Residual norm: 6.758358082942363e-08
# Iteration 2, Residual norm: 1.766858153929019e-15
#
# Iteration 0, Residual norm: 0.00039900595008188813
# Iteration 1, Residual norm: 6.487809658798917e-08
# Iteration 2, Residual norm: 1.6643309956901927e-15
#
# Iteration 0, Residual norm: 0.00039030313509468484
# Iteration 1, Residual norm: 6.227045572760148e-08
# Iteration 2, Residual norm: 1.5313009906374754e-15
# Progress: 28%, Time: 8.40e+00, accepted step: True, dt: 6.00e-02, iterations: 2
#
# Iteration 0, Residual norm: 0.0003794728416877511
# Iteration 1, Residual norm: 5.959200065520227e-08
# Iteration 2, Residual norm: 1.3916386767796084e-15
#
# Iteration 0, Residual norm: 0.0003715310730747562
# Iteration 1, Residual norm: 5.725682552643587e-08
# Iteration 2, Residual norm: 1.3084613919298548e-15
#
# Iteration 0, Residual norm: 0.0003652872494626594
# Iteration 1, Residual norm: 5.499586471942584e-08
# Iteration 2, Residual norm: 1.2329991425816115e-15
#
# Iteration 0, Residual norm: 0.00035609958833544044
# Iteration 1, Residual norm: 5.270105586902022e-08
# Iteration 2, Residual norm: 1.1374132528077369e-15
#
# Iteration 0, Residual norm: 0.00034623366277197114
# Iteration 1, Residual norm: 5.045915688739078e-08
# Iteration 2, Residual norm: 1.042191140088399e-15
#
# Iteration 0, Residual norm: 0.000339896512090442
# Iteration 1, Residual norm: 4.845054759629759e-08
# Iteration 2, Residual norm: 9.88440424763852e-16
#
# Iteration 0, Residual norm: 0.0003340708015556867
# Iteration 1, Residual norm: 4.651816830603995e-08
# Iteration 2, Residual norm: 9.3009689602436e-16
#
# Iteration 0, Residual norm: 0.0003253815354291081
# Iteration 1, Residual norm: 4.454870355098632e-08
# Iteration 2, Residual norm: 8.601984036750954e-16
#
# Iteration 0, Residual norm: 0.000317299952352751
# Iteration 1, Residual norm: 4.2709686161906314e-08
# Iteration 2, Residual norm: 7.998641380901036e-16
#
# Iteration 0, Residual norm: 0.0003121583685191819
# Iteration 1, Residual norm: 4.104112989269559e-08
# Iteration 2, Residual norm: 7.704636979771993e-16
#
# Iteration 0, Residual norm: 0.000305970488677598
# Iteration 1, Residual norm: 3.938232605123957e-08
# Iteration 2, Residual norm: 7.328056713282196e-16
#
# Iteration 0, Residual norm: 0.0002973995472248302
# Iteration 1, Residual norm: 3.7677640706866146e-08
# Iteration 2, Residual norm: 6.840804482404037e-16
#
# Iteration 0, Residual norm: 0.00029068295363659645
# Iteration 1, Residual norm: 3.6150976912638994e-08
# Iteration 2, Residual norm: 6.464956442355576e-16
#
# Iteration 0, Residual norm: 0.00028629991912886726
# Iteration 1, Residual norm: 3.47050061690779e-08
# Iteration 2, Residual norm: 6.341459816063265e-16
#
# Iteration 0, Residual norm: 0.000280100596779496
# Iteration 1, Residual norm: 3.329207775379418e-08
# Iteration 2, Residual norm: 6.058085502558097e-16
#
# Iteration 0, Residual norm: 0.00027248831158511994
# Iteration 1, Residual norm: 3.185550625153676e-08
# Iteration 2, Residual norm: 5.693553040160954e-16
#
# Iteration 0, Residual norm: 0.00026723933927484976
# Iteration 1, Residual norm: 3.06034481035678e-08
# Iteration 2, Residual norm: 5.56000375474325e-16
#
# Iteration 0, Residual norm: 0.0002630301175146523
# Iteration 1, Residual norm: 2.938282459300269e-08
# Iteration 2, Residual norm: 5.33249127007774e-16
#
# Iteration 0, Residual norm: 0.000256489874315736
# Iteration 1, Residual norm: 2.8144930277792504e-08
# Iteration 2, Residual norm: 5.192665576977444e-16
#
# Iteration 0, Residual norm: 0.00024967899307457367
# Iteration 1, Residual norm: 2.6951226880008986e-08
# Iteration 2, Residual norm: 5.117871649501249e-16
#
# Iteration 0, Residual norm: 0.00024548336158320154
# Iteration 1, Residual norm: 2.587904981561328e-08
# Iteration 2, Residual norm: 5.04979897677727e-16
#
# Iteration 0, Residual norm: 0.00024132970984306967
# Iteration 1, Residual norm: 2.4842354450222415e-08
# Iteration 2, Residual norm: 4.823703802863652e-16
#
# Iteration 0, Residual norm: 0.0002350227659134912
# Iteration 1, Residual norm: 2.377847449280852e-08
# Iteration 2, Residual norm: 4.774014223356522e-16
#
# Iteration 0, Residual norm: 0.00022943562786391716
# Iteration 1, Residual norm: 2.2801363773577066e-08
# Iteration 2, Residual norm: 4.72625288286879e-16
#
# Iteration 0, Residual norm: 0.0002259699627203246
# Iteration 1, Residual norm: 2.1901910128491888e-08
# Iteration 2, Residual norm: 4.660993937181311e-16
# Progress: 33%, Time: 9.90e+00, accepted step: True, dt: 6.00e-02, iterations: 2
#
# Iteration 0, Residual norm: 0.0002214963923621486
# Iteration 1, Residual norm: 2.101039461305796e-08
# Iteration 2, Residual norm: 4.645737909066551e-16
#
# Iteration 0, Residual norm: 0.00021537298805901178
# Iteration 1, Residual norm: 2.009750691225105e-08
# Iteration 2, Residual norm: 4.560188107144114e-16
#
# Iteration 0, Residual norm: 0.00021080020960934716
# Iteration 1, Residual norm: 1.9286947130593444e-08
# Iteration 2, Residual norm: 4.567454831791582e-16
#
# Iteration 0, Residual norm: 0.00020774389125590762
# Iteration 1, Residual norm: 1.8514318696076405e-08
# Iteration 2, Residual norm: 4.556766911103772e-16
#
# Iteration 0, Residual norm: 0.0002031594207476196
# Iteration 1, Residual norm: 1.7752388992968287e-08
# Iteration 2, Residual norm: 4.474039135439757e-16
#
# Iteration 0, Residual norm: 0.00019771880471568007
# Iteration 1, Residual norm: 1.698710262257926e-08
# Iteration 2, Residual norm: 4.449156054134882e-16
#
# Iteration 0, Residual norm: 0.00019413975516786996
# Iteration 1, Residual norm: 1.6317804816746415e-08
# Iteration 2, Residual norm: 4.464278408525931e-16
#
# Iteration 0, Residual norm: 0.0001911187588068635
# Iteration 1, Residual norm: 1.5663229436790062e-08
# Iteration 2, Residual norm: 4.4057016099591185e-16
#
# Iteration 0, Residual norm: 0.0001863284757577729
# Iteration 1, Residual norm: 1.4998117426678726e-08
# Iteration 2, Residual norm: 4.3852485641258703e-16
#
# Iteration 0, Residual norm: 0.00018154937984772655
# Iteration 1, Residual norm: 1.4365370495622152e-08
# Iteration 2, Residual norm: 4.4124137833144795e-16
#
# Iteration 0, Residual norm: 0.000178679360475699
# Iteration 1, Residual norm: 1.3793638999496765e-08
# Iteration 2, Residual norm: 4.3729628179268385e-16
#
# Iteration 0, Residual norm: 0.00017560421504103638
# Iteration 1, Residual norm: 1.3238834382935413e-08
# Iteration 2, Residual norm: 4.287756633179469e-16
#
# Iteration 0, Residual norm: 0.00017097901959469469
# Iteration 1, Residual norm: 1.2667545518367045e-08
# Iteration 2, Residual norm: 4.4340494519068046e-16
#
# Iteration 0, Residual norm: 0.0001670784269698014
# Iteration 1, Residual norm: 1.215002029618151e-08
# Iteration 2, Residual norm: 4.297489757489936e-16
#
# Iteration 0, Residual norm: 0.00016465694025044378
# Iteration 1, Residual norm: 1.1667633097196499e-08
# Iteration 2, Residual norm: 4.303221965791081e-16
#
# Iteration 0, Residual norm: 0.00016133248348151923
# Iteration 1, Residual norm: 1.1190100695930424e-08
# Iteration 2, Residual norm: 4.3728746063624745e-16
#
# Iteration 0, Residual norm: 0.00015691801284060364
# Iteration 1, Residual norm: 1.0703329582106865e-08
# Iteration 2, Residual norm: 4.2926374412458396e-16
#
# Iteration 0, Residual norm: 0.0001537668734775158
# Iteration 1, Residual norm: 1.0273653904948613e-08
# Iteration 2, Residual norm: 4.3156075403911157e-16
#
# Iteration 0, Residual norm: 0.00015156641221088834
# Iteration 1, Residual norm: 9.861539708832403e-09
#
# Iteration 0, Residual norm: 0.00014813818065983252
# Iteration 1, Residual norm: 9.451918142095337e-09
#
# Iteration 0, Residual norm: 0.00014424194214711808
# Iteration 1, Residual norm: 9.045957912851806e-09
#
# Iteration 0, Residual norm: 0.000141769423293314
# Iteration 1, Residual norm: 8.688923398806408e-09
#
# Iteration 0, Residual norm: 0.00013954265541389255
# Iteration 1, Residual norm: 8.339228255840072e-09
#
# Iteration 0, Residual norm: 0.00013600683482683314
# Iteration 1, Residual norm: 7.982727969622381e-09
#
# Iteration 0, Residual norm: 0.00013264322170412148
# Iteration 1, Residual norm: 7.64826086020961e-09
# Progress: 38%, Time: 1.14e+01, accepted step: True, dt: 6.00e-02, iterations: 1
#
# Iteration 0, Residual norm: 0.00013064559878132984
# Iteration 1, Residual norm: 7.343638792556851e-09
#
# Iteration 0, Residual norm: 0.00012833552772610228
# Iteration 1, Residual norm: 7.0471329347029576e-09
#
# Iteration 0, Residual norm: 0.0001249416758307
# Iteration 1, Residual norm: 6.7414902827033644e-09
#
# Iteration 0, Residual norm: 0.00012221566246538472
# Iteration 1, Residual norm: 6.467778765699377e-09
#
# Iteration 0, Residual norm: 0.00012049006932619927
# Iteration 1, Residual norm: 6.209859225333319e-09
#
# Iteration 0, Residual norm: 0.00011799808628336655
# Iteration 1, Residual norm: 5.95440359794075e-09
#
# Iteration 0, Residual norm: 0.00011481472084536411
# Iteration 1, Residual norm: 5.695636203075602e-09
#
# Iteration 0, Residual norm: 0.00011263459346703672
# Iteration 1, Residual norm: 5.467948253515934e-09
#
# Iteration 0, Residual norm: 0.00011102142350311763
# Iteration 1, Residual norm: 5.248383728323647e-09
#
# Iteration 0, Residual norm: 0.00010845504845814047
# Iteration 1, Residual norm: 5.02853435922892e-09
#
# Iteration 0, Residual norm: 0.00010567222742285719
# Iteration 1, Residual norm: 4.813763161209454e-09
#
# Iteration 0, Residual norm: 0.00010395438246907377
# Iteration 1, Residual norm: 4.623485022286834e-09
#
# Iteration 0, Residual norm: 0.0001022919821482408
# Iteration 1, Residual norm: 4.437026439225607e-09
#
# Iteration 0, Residual norm: 9.968393560196244e-05
# Iteration 1, Residual norm: 4.2462466769828025e-09
#
# Iteration 0, Residual norm: 9.732007416568169e-05
# Iteration 1, Residual norm: 4.0697141457919305e-09
#
# Iteration 0, Residual norm: 9.591502930979639e-05
# Iteration 1, Residual norm: 3.907449673564755e-09
#
# Iteration 0, Residual norm: 9.417036558890659e-05
# Iteration 1, Residual norm: 3.749056557648801e-09
#
# Iteration 0, Residual norm: 9.169021752768087e-05
# Iteration 1, Residual norm: 3.5859777437259295e-09
#
# Iteration 0, Residual norm: 8.978827466286499e-05
# Iteration 1, Residual norm: 3.4412523949856214e-09
#
# Iteration 0, Residual norm: 8.854404313029436e-05
# Iteration 1, Residual norm: 3.3036060649827484e-09
#
# Iteration 0, Residual norm: 8.667359603442703e-05
# Iteration 1, Residual norm: 3.1669683322962104e-09
#
# Iteration 0, Residual norm: 8.438689001732151e-05
# Iteration 1, Residual norm: 3.0297067476154472e-09
#
# Iteration 0, Residual norm: 8.287652918918429e-05
# Iteration 1, Residual norm: 2.9089875761906197e-09
#
# Iteration 0, Residual norm: 8.168208600902637e-05
# Iteration 1, Residual norm: 2.7920645927551247e-09
#
# Iteration 0, Residual norm: 7.976674509062118e-05
# Iteration 1, Residual norm: 2.6741873048030464e-09
# Progress: 43%, Time: 1.29e+01, accepted step: True, dt: 6.00e-02, iterations: 1
#
# Iteration 0, Residual norm: 7.778968116726293e-05
# Iteration 1, Residual norm: 2.560744544571324e-09
#
# Iteration 0, Residual norm: 7.659141540242926e-05
# Iteration 1, Residual norm: 2.4593569066569878e-09
#
# Iteration 0, Residual norm: 7.53440537695457e-05
# Iteration 1, Residual norm: 2.3599942026611843e-09
#
# Iteration 0, Residual norm: 7.342805454686945e-05
# Iteration 1, Residual norm: 2.258016727500175e-09
#
# Iteration 0, Residual norm: 7.177364052971661e-05
# Iteration 1, Residual norm: 2.1648903150093705e-09
#
# Iteration 0, Residual norm: 7.077719098427716e-05
# Iteration 1, Residual norm: 2.078457498625187e-09
#
# Iteration 0, Residual norm: 6.946035199590266e-05
# Iteration 1, Residual norm: 1.9938332755126685e-09
#
# Iteration 0, Residual norm: 6.765904498053152e-05
# Iteration 1, Residual norm: 1.9070028681140207e-09
#
# Iteration 0, Residual norm: 6.633719191995196e-05
# Iteration 1, Residual norm: 1.8304484883019995e-09
#
# Iteration 0, Residual norm: 6.543228878977847e-05
# Iteration 1, Residual norm: 1.7570723604292087e-09
#
# Iteration 0, Residual norm: 6.403321988156012e-05
# Iteration 1, Residual norm: 1.6839716593707768e-09
#
# Iteration 0, Residual norm: 6.240044105309347e-05
# Iteration 1, Residual norm: 1.6112919890411904e-09
#
# Iteration 0, Residual norm: 6.135483120926028e-05
# Iteration 1, Residual norm: 1.5472338256666964e-09
#
# Iteration 0, Residual norm: 6.04654106756406e-05
# Iteration 1, Residual norm: 1.4849854188024161e-09
#
# Iteration 0, Residual norm: 5.904546521948328e-05
# Iteration 1, Residual norm: 1.421833887934594e-09
#
# Iteration 0, Residual norm: 5.765060287761707e-05
# Iteration 1, Residual norm: 1.3619755864237509e-09
#
# Iteration 0, Residual norm: 5.681297410606891e-05
# Iteration 1, Residual norm: 1.3079518120827759e-09
#
# Iteration 0, Residual norm: 5.587621253612841e-05
# Iteration 1, Residual norm: 1.2550024915778152e-09
#
# Iteration 0, Residual norm: 5.447886702144025e-05
# Iteration 1, Residual norm: 1.2005586538418946e-09
#
# Iteration 0, Residual norm: 5.33275919314238e-05
# Iteration 1, Residual norm: 1.1514303902026864e-09
#
# Iteration 0, Residual norm: 5.261700601351757e-05
# Iteration 1, Residual norm: 1.1053932747423978e-09
#
# Iteration 0, Residual norm: 5.162727066841817e-05
# Iteration 1, Residual norm: 1.0601649260302842e-09
#
# Iteration 0, Residual norm: 5.033073766312263e-05
# Iteration 1, Residual norm: 1.0140186275897068e-09
#
# Iteration 0, Residual norm: 4.941638354864711e-05
# Iteration 1, Residual norm: 9.73493240394257e-10
#
# Iteration 0, Residual norm: 4.875501173296925e-05
# Iteration 1, Residual norm: 9.344072664301126e-10
# Progress: 48%, Time: 1.44e+01, accepted step: True, dt: 6.00e-02, iterations: 1
#
# Iteration 0, Residual norm: 4.771539430268129e-05
# Iteration 1, Residual norm: 8.952878316511126e-10
#
# Iteration 0, Residual norm: 4.655984462975562e-05
# Iteration 1, Residual norm: 8.568598819625548e-10
#
# Iteration 0, Residual norm: 4.583692510540233e-05

# %% [markdown]
# ### Postprocessing

# %%
output_dir = "./output_navier_stokes"
os.makedirs(output_dir, exist_ok=True)

history = result.history
timesteps = history.t
velocity_history = history.q['1velocity']
pressure_history = history.q['2pressure']
temperature_history = history.q['3temperature']

# Export one VTK file for each time step
for i, t_val in enumerate(timesteps):
  # Export velocity and temperature
  point_data = {
      'velocity': jnp.pad(velocity_history[i], ((0, 0), (0, 1)), constant_values=0),
      'temperature': temperature_history[i],
  }
  meshio.Mesh(
      points=jnp.pad(coords_v, ((0, 0), (0, 1)), constant_values=0),
      cells={
          'triangle6': cells_v
      },
      point_data=point_data,
  ).write(f"{output_dir}/navier_stokes_t{i}.vtk")

  # Export pressure
  point_data = {
      'pressure': pressure_history[i],
  }
  meshio.Mesh(
      points=jnp.pad(coords_p, ((0, 0), (0, 1)), constant_values=0),
      cells={
          'triangle': cells_p
      },
      point_data=point_data,
  ).write(f"{output_dir}/navier_stokes_p_t{i}.vtk")
